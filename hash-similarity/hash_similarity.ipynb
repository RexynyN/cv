# %%
import os 
import cv2
import random
import numpy as np 
import imagehash as ih
from uuid import uuid4
from PIL import Image, ImageFilter, ImageOps
from multiprocessing import Pool
from os.path import join as path_join


BASE_PATH = path_join("data")
IMAGES_PATH = path_join(BASE_PATH, "original")
MODIFIED_PATH = path_join(BASE_PATH, "mod")
TRASH_PATH = path_join(BASE_PATH, "__trash__")

os.makedirs(TRASH_PATH, exist_ok=True)

# %%
def unique_photo():
    # Create a uuid for each image, for uniformity
    for img in os.listdir(IMAGES_PATH):
        ext = img.split(".")[-1]
        original = path_join(IMAGES_PATH, img)
        mod = path_join(IMAGES_PATH, f"{uuid4()}.{ext}")
        os.rename(original, mod)

# unique_photo()

# %%
def worsen_resolution(image: str):
    resolutions = (95, 75, 50, 40, 30, 20, 10, 5, 1) # A list of predetermined resolutions
    print(image)

    tokens = image.split(".")
    basefile, ext = tokens[0], tokens[-1]

    mod_path = path_join(MODIFIED_PATH, basefile)
    os.makedirs(mod_path, exist_ok=True)

    img = Image.open(path_join(IMAGES_PATH, image))
    for res in resolutions:
        save_path = path_join(mod_path, f"img-res-{res}.{ext}")
        img.save(save_path, quality=res)

# with Pool(processes=10) as pool:
#     pool.map(worsen_resolution, os.listdir(IMAGES_PATH))

# %%
ALPHABET = "0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
FILTERS = [
    ImageFilter.GaussianBlur(2),
    ImageFilter.EDGE_ENHANCE_MORE,
    ImageFilter.ModeFilter(7),
    ImageFilter.MaxFilter(3),
    ImageFilter.MinFilter(3),
    ImageFilter.MedianFilter(5),
]
FILTERS_LEN = len(FILTERS)

# A random chance of the transformation occuring
def should_apply(percentage: float=0.5):
    return random.random() < percentage

# Create a new filename for an augmented image
def new_filename(name: str):
    tokens = name.split(".")
    if len(tokens) > 2: # For weird paths
        tokens = [''.join(tokens[:-1]), tokens[-1]]
    path, extension = tokens

    # Adds salt, because an image can have multiple augmented versions
    salt = ''.join(random.choice(ALPHABET) for _ in range(6))
    return f"{path}-aug-{salt}.{extension}"

# Data Augmentation 
def data_augmentation(filepath: str, outpath: str, num_variations: int=5):
    # # Give a random chance of not having an augmented version of the image 
    # if should_apply(0.1) and num_variations == 0: return 
    # # And a chance of having multiple augmented versions 
    # if should_apply(0.3) and num_variations == 0: data_augmentation(filepath, save=save)

    ext = filepath.split(".")[-1]
    for _ in range(num_variations):
        name = "img-"
        img = Image.open(filepath)
        if should_apply(0.5):
            # Mirror the image on its vertical axis.
            name += "mir-"
            img = ImageOps.mirror(img)
        
        if should_apply(0.4):
            # We do not want to flip it upside down, because is hard that a real image
            # will be supplied flipped. But an angled face is very common.
            angle = random.randint(-90, 90)
            name += f"r{angle}-"
            img = img.rotate(angle)

        # if should_apply(0.2):
        #     if should_apply(0.5):
        #         # Returns a grayscale image
        #         img = ImageOps.grayscale(img) 
        #     else: 
        #         # It'll create a kinda dithered B&W image
        #         img = img.convert('1')

        # Be sure that the image is in the right format before filters
        if img.mode != "RGB":
            img = img.convert("RGB")
        
        # # Apply a random filter
        # if should_apply(0.6):
        #     idx = random.randint(0, FILTERS_LEN)
        #     if idx == FILTERS_LEN:
        #         # Those filters don't have a dedicated class, so we do a little trolling
        #         if should_apply(0.5):
        #             img = img.effect_spread(5)
        #         elif should_apply(0.5):
        #             # Filter a # of colors from the image
        #             color_scale = [8, 16, 14, 32, 48, 64]
        #             img = img.convert('P', 
        #                             palette=Image.ADAPTIVE, 
        #                             colors=random.choice(color_scale))
        #             img = img.convert("RGB")
        #         else:
        #             # Adds some noise
        #             img = img.convert('P', palette=Image.BICUBIC)
        #             img = img.convert("RGB")
        #     else:
        #         img = img.filter(FILTERS[idx])

        res = random.choice((95, 75, 50, 40, 30, 20, 10, 5, 1))
        name += f"q{res}.{ext}"
        img.save(name, quality=res)

  
data_augmentation("image.jpg", ".", 70)

# %%
for hosh in hashes:
    print(hosh["img"], ":")
    if hosh["avg"] == original["avg"]:
        print("Average:", original["avg"] - hosh["avg"], "=>", hosh["avg"] == original["avg"])

    if hosh["crop"] == original["crop"]:
        print("Crop Resistant:", original["crop"] - hosh["crop"], "=>", hosh["crop"] == original["crop"])
    
    if hosh["whash"] == original["whash"]:
        print("Wavelet:", original["whash"] - hosh["whash"], "=>", hosh["whash"] == original["whash"])
    
    if hosh["phash"] == original["phash"]:
        print("Perceptual:", original["phash"] - hosh["phash"], "=>", hosh["phash"] == original["phash"])
    
    if hosh["dhash"] == original["dhash"]:
        print("Difference:", original["dhash"] - hosh["dhash"], "=>", hosh["dhash"] == original["dhash"])
    
    if hosh["color"] == original["color"]:
        print("Color:", original["color"] - hosh["color"], "=>", hosh["color"] == original["color"])
    print()

# %%
for hosh in hashes:
    print(hosh["img"], ":")
    print("Average:", hosh["avg"])
    print("Crop Resistant:", hosh["crop"])
    print("Wavelet:", hosh["whash"])
    print("Perceptual:", hosh["phash"])
    print("Difference:", hosh["dhash"])
    print("Color:", hosh["color"])
    print()
# Out:
# img-mir-q95.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,1899d80c8d9b1f27,dc2de99a909648e1,a498c97c365a7a1e,1b0380038f98f03f,322b6959d48c9e2d,8d94f323a38c8c72,c00f0e38343c8fa6,2fe3953965114521,193931303633111a
# Wavelet: c706ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94f323a38c8c72
# Color: 0a202008000
#
# img-r-55-q50.jpg :
# Average: 0e7c4e0edf9bfc30
# Crop Resistant: b9b471d18d8f4eee,647861e4c4a6d290,b47630b933264c1d,a070ec6edaf23c4f,3a6e1c3c61cd8b33,c61e4d5a36868eec,7ce0d8b83232b0d0,4d1e3d3dbc0e2d4c,6c3911338d9fc3e7
# Wavelet: 067c0e0edf9bdc30
# Perceptual: 911646bd3e163d78
# Difference: 7ce0d8b83232b0d0
# Color: 11202008000
#
# img-q1.jpg :
# Average: e742ff998e272318
# Crop Resistant: d9d0c6c7e6682d6d,e666e5cd4c64071a,c44b69a6e79627c9,ced89ce6f2f83693,1c0e26d3f234e183,d0d0999192a48892,4cd630333aceceb1,36073371611382a7,3d0d2f37251f3377
# Wavelet: e362ff998e272218
# Perceptual: 9ff80027faea86d0
# Difference: 4cd630333aceceb1
# Color: 01001208000
#
# img-q75.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,a766e4cf4e26071b,c44b68a6f696ed78,dae66cc192a5a187,273ffe3f0ee6f003,b32b6965c4ce864b,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359355d7b,3e2d3737251f3b77
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 0a202008000
#
# img-mir-r-77-q40.jpg :
# Average: 013ffefe9fe7ce00
# Crop Resistant: e1959a18cdf2d0da,cfa278f2ce8a8e7c,13560c1cf0f28682,25b12814a6d99a06,325cd85cccddc800,3bd9e8108a467131,3fa9cc786cce9890,c4949c8c3c171f5b,6627b5f3f03062cc
# Wavelet: 013ffcfe16e38e00
# Perceptual: 948e282f1f91677a
# Difference: 3fa9cc786cce9890
# Color: 11202008000
#
# img-q50.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,a766e4cf4e26071b,c44b68a6f696ed78,dae66cc193a5a187,273ffe3f0ee6f003,b32b6965c4ce8649,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359374d7b,3e2d3737251f3b77
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 0a202000000
#
# img-mir-r-47-q95.jpg :
# Average: 1c385efffb93f630
# Crop Resistant: cca9bb96b829a734,5026f6cd9b868cb1,7933f13cbcc0e0c6,66aecc1933e1c104,edb070c8c081e0d8,62b13cdefc384e27,7ce29d282336a4e1,c386333133f36363
# Wavelet: 0c385effd393f200
# Perceptual: c49b463d4bd63872
# Difference: 7ce29d282336a4e1
# Color: 11202008000
#
# img-r-12-q50.jpg :
# Average: 706bff9d1d6eee36
# Crop Resistant: 6cc8cac7e65858d2,c7f6c2cd8d8d0436,6f7aec7e3a088ca3,23253476f3b6ee72,2261e99574ccf63f,c48aba3979dc9ce4,5e374ec233073a4c,84bd3e33793dcf5b,1f171517250f3776
# Wavelet: 706afe8d0f2ece10
# Perceptual: 91e844275efe54d8
# Difference: c48aba3979dc9ce4
# Color: 09202008000
#
# img-mir-q10.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64f4941c98e94b49,1a99580c8d9b1f27,dc2d699a909648e1,1b0380038f98f03f,322b6959dc8c9e25,8d94b323a38c8c72,871e17717973bc1a,2fe3953961134521,834f1b135b432311
# Wavelet: c714ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94b323a38c8c72
# Color: 01202000000
#
# img-mir-q1.jpg :
# Average: e742ff9971e4c418
# Crop Resistant: 64f49c1c98e94b49,9889584ccdd91fa7,dc2d699a18961b4c,1b0b8003cf9cf038,f4f46676a6128e36,8d94f333a38c8c72,931f33717933bc1a,034d0b135b032311
# Wavelet: c746ff9971e44418
# Perceptual: caa91572aabfd380
# Difference: 8d94f333a38c8c72
# Color: 01001208000
#
# img-mir-r-57-q5.jpg :
# Average: 0e3ceeff9fb3e620
# Crop Resistant: efa4999f6c58a567,29a0f6c68b868d31,2dd171b9bcdcc18e,36660c9833e3c302,84f3e8d47ab4e47a,cb397cc44080e0d8,7cf1d8682666ccc9,8b963231f34347c6
# Wavelet: 063ceeff9783a420
# Perceptual: 9799033d0af63d70
# Difference: 7cf1d8682666ccc9
# Color: 11202008000
#
# img-q10.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9d0c6c7e6682d6d,a766e4cf4e26071b,c44b68a6f696e578,272ffe3f0ee6f003,b32b6965c4ce8659,0cd6303b3aceceb1,1e0717716131c2a7,0b38566379374d7b,3e0d2727251d3b77
# Wavelet: e328ff9d8e272218
# Perceptual: 9ff80027dae286d5
# Difference: 0cd6303b3aceceb1
# Color: 01202000000
#
# img-q5.jpg :
# Average: e742ff9d8e272318
# Crop Resistant: d9d8c6c7e6682d6d,c726e4cf4e26071b,c44b68a6f696e778,273ffe3f0ee6e003,236969d4d4cc8678,0cd6323b38ceceb1,3c0f0fe3d3c30e9a,0b38566359754d7b,3e4d2f25451d3367,e9f23c4f3305ffee
# Wavelet: e362ff998e272218
# Perceptual: 9ff80027daea86d1
# Difference: 0cd6323b38ceceb1
# Color: 02002000000
#
# img-r-5-q20.jpg :
# Average: 606aff9d8f266618
# Crop Resistant: c8dcc0d2c7e7e648,c7e6c4cd4c240712,6a6934b7d386e938,2feffe3e1c84f041,2a3438e3c3a7878f,a26969d5a44ec6fb,86d2b0397acecef2,fe0f8e4393830e36,09187e63793d5f5b,1f2f1717251d3777
# Wavelet: 606afe9d8f266a18
# Perceptual: 91e844275efa86dc
# Difference: 86d2b0397acecef2
# Color: 09202000000
#
# img-mir-q5.jpg :
# Average: e742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,189bd80c8d9b1f27,dc2de99a909618e1,a498c97c365a7a1a,1b0380038f98f03f,3b6969d494cc9e61,cc94b323e38c8c72,c30f0f38343c8fa6,2fe3953961114d21,830d035b5d473311,68b0c30c30570088
# Wavelet: c746ff9971e44418
# Perceptual: caa91572aabfd380
# Difference: cc94b323e38c8c72
# Color: 02002000000
#
# img-mir-q30.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,1899580c8d9b1f27,dc2de99a909648e1,a498c97c365a3a1e,1b0380038f98f03f,322b6959dc8c9e2d,8d94f323a38c8c72,c00f0e38343c8fa6,2fe3953961114d21,834f13135b472311
# Wavelet: c706ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94f323a38c8c72
# Color: 0a202008000
#
# img-r63-q1.jpg :
# Average: 60bc777ff9cd6702
# Crop Resistant: 0c8ae36388f02c9c,577eb0982e1ec771,b791cde6b2383c0f,c461624646c47c0f,db3864ca90c2606d,2d61c9fdfd7cf2c6,8070e6e01b99cc6c,33c99c38181a074e
# Wavelet: 60bc777fe9c52600
# Perceptual: c2c956695da73827
# Difference: 8070e6e01b99cc6c
# Color: 09001208000
#
# img-mir-r15-q40.jpg :
# Average: 0c96ffb9b876772c
# Crop Resistant: 59c9ac1c18d4e4d6,3010b84c0e6ecf93,05a0c881b3e66c79,5252d39130928cb1,b3a94851d6c89002,dc2aa26360c4c6d8,09351e3d321ea3e4,dece823361434ca5,0e060f17530b1391
# Wavelet: 0c9a7eb1b8767328
# Perceptual: c4fd11565ba9419d
# Difference: dc2aa26360c4c6d8
# Color: 09202008000
#
# img-q30.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,a766e4cf4e26071b,c44b68a6f696ed78,dae46cc193a5a187,273ffe3f0ee6f003,b32b6965c4ce8649,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359374d7b,676373f3933377a7
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 0a202000000
#
# img-mir-r-85-q20.jpg :
# Average: 00fff6be9ee79e00
# Crop Resistant: e09199988cb2b4d8,643338d8624e8a1c,4b4e1cbcf653a7a7,9424385a6638bc62,9f4c6c4dccd9c988,b8d84830988cc5e3,9ba9cc706c8d34b0,e2988c8c1d1f1f5f,0b2337793838304c
# Wavelet: 007ff6be16c79e00
# Perceptual: 94a3283b1d9d635e
# Difference: 9ba9cc706c8d34b0
# Color: 11202008000
#
# img-mir-q75.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c1898e8,1899d80c8d9b1f27,dc2de99a909648e1,a498c97c365a7a1a,1b0380038f98f03f,322b6959dc8c9e2d,8d94f323a38c8c72,c00f0e38343c8fa6,2fe3953961114521,834b13135b072311
# Wavelet: c706ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94f323a38c8c72
# Color: 0a202008000
#
# img-q95.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,a766e4cf4e26071b,c44b68a6f696ed78,dae66cc192a5a187,273ffe3f0ee6f003,b32b6965c4ce864b,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359375d7b,676373f3933377a7
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 0a202008000
#
# img-mir-q40.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,1899d80c8d9b1f27,dc2d699a909648e1,a498c97c365a3a1a,1b0380038f98f03f,322b6959dc8c9e2d,8d94f323a38c8c72,c00f0c38343c8fa6,2fe3953965114521,834f03135b472311
# Wavelet: c706ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94f323a38c8c72
# Color: 0a202008000
#
# img-r-69-q40.jpg :
# Average: 023f0ece9fbbfc60
# Crop Resistant: 75d29989cdcd6eb6,b336f0b4444ca638,72b2b33038634f0e,e6306c7a4d8851a1,afa6be76e4810b0d,960e49322c1dd860,76f3e89c3076e080,8d3e3cbd0c2c4e4d,63761831031d86c7
# Wavelet: 023f0cce9fbb7c40
# Perceptual: 951741bd70752d1e
# Difference: 76f3e89c3076e080
# Color: 11202008000
#
# img-q20.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,e766e4cf4e26071b,c44b69a6f696e778,dae66cc193a5a187,273ffe3f0ee6f003,b22b6961c4ce864b,0cd6303b3aceceb1,fc0fcfe3d3c30e9a,0b38566359354d7b,3e0d3727251f3b77
# Wavelet: e328ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 01202000000
#
# img-mir-r51-q20.jpg :
# Average: 783e7270fbf93f1c
# Crop Resistant: 60d271744e8e8d89,dce179d89c9aa5f4,d292f362329bcf47,a381c5e1794c2673,f8f3c982a0e18208,98c64ba5b39a8edc,c0f8c6e0b2b3f230,76f1a1393d968df9,3d4f838334b433bb,6163331b2e0e3c98
# Wavelet: 303c7270fbd93f04
# Perceptual: c4c313ea4f4768ad
# Difference: c0f8c6e0b2b3f230
# Color: 11202008000
#
# img-mir-r-85-q40.jpg :
# Average: 00fff6be9ee79e00
# Crop Resistant: e0919b988cbab4d8,647338d8624e8a0e,4b461cfef653a7a7,9424387266b8d861,9f4c6c4dccd9c988,b8d94830188cc5e3,9ba9cc706c8d34b0,e2988c8c1d1f1f5f,0b2337793838304c
# Wavelet: 007ff6be16c79e00
# Perceptual: 94a3283b1d9d635e
# Difference: 9ba9cc706c8d34b0
# Color: 11202008000
#
# img-r57-q20.jpg :
# Average: 703c77fff9cd6704
# Crop Resistant: 28da6606c9611b19,4bba90dc2e9e4673,62743162c2e43c8e,9399cde633383c3f,bef0c081c0d0a184,2c63c1dcfdfefae4,c070e4e99b99cc6c,289693733330351d
# Wavelet: 603c777fe9c12704
# Perceptual: c2cc57695fa36825
# Difference: c070e4e99b99cc6c
# Color: 11202008000
#
# img-r-65-q50.jpg :
# Average: 063f0ece9fbbfc70
# Crop Resistant: 3572d999cdcf6e36,be34f0f4c44e9628,b476b5b031674e1c,6090bc3bd464d4f9,6b2ebe76e4810d1b,962e4d32241c8c60,76d1d89c3072e0c0,8d1e3cbd0c2c4e4d,677c1931031d87c7
# Wavelet: 023f0cce9fbb7c40
# Perceptual: 951744bd7475351a
# Difference: 76d1d89c3072e0c0
# Color: 11202008000
#
# img-q40.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,a766e4cf4e26071b,c44b68a6f696ed78,dae66cc192a5a187,273ffe3f0ee6f003,b32b6961c4ce8649,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359374d7b,3e2d3737251f3b77
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 0a202000000
#
# img-mir-r-63-q30.jpg :
# Average: 063deefe9fb3e640
# Crop Resistant: e3a69899665869e6,1591f2e68b871c73,12760c98b2e3c303,cc79b99d9ddcc002,85d1ecf6e989e879,8b794cc000c1b0bc,3ef198f82666ccc8,9b3632b1f356cfe6
# Wavelet: 063ceefe97a3e400
# Perceptual: 979d033d0cd56572
# Difference: 3ef198f82666ccc8
# Color: 11202008000
#
# img-r22-q10.jpg :
# Average: 0c8efaffcfd3123c
# Crop Resistant: 28b69387c270f6cb,cc9ce4cb47b0c167,7298e3b85c742629,73d36369b1f0cce7,c9bdbcfa7c7e70b1,b0e0c3c2c8918208,d828a2323aa7f6e8,ac69e7615f3e179f,7e4b067161f191d3
# Wavelet: 0c8efefe8f81121c
# Perceptual: 9cd7063a5b0d489f
# Difference: d828a2323aa7f6e8
# Color: 09202008000
#
# img-r82-q95.jpg :
# Average: 00fe6f7d79e77900
# Crop Resistant: 785626e7ccb2f6a5,d813e3e48c8c8ec7,359dcf87b030189e,266df3d191a3445a,23c5cdcdcc64ecff,e26ce8f6aedd5939,226accf1c94ed3f2,b8c6c6cec3070705
# Wavelet: 00fe2f7d78e77100
# Perceptual: c1d67d6e48c8370b
# Difference: 226accf1c94ed3f2
# Color: 11202008000
#
# img-mir-r58-q75.jpg :
# Average: 60fe7072fbd93f0c
# Crop Resistant: 42b170644e0d8c88,8ac179d8dc9bb4f6,9291f2721b8dc33b,faf1c08892b8a082,ab8983c3795c0e33,9cc74da1d39eceec,c07ce4c233b3f23c,4d874343ca8b4dcd,c96367324e063c18
# Wavelet: 603e7070f9d93f0c
# Perceptual: c0c713e96f63682d
# Difference: c07ce4c233b3f23c
# Color: 11202008000
#
# image.jpg :
# Average: e342ff9d8e272318
# Crop Resistant: d9dcc0d6c7e6e6e8,e766e4cf4e26071b,c44b68a6f696ed78,dae46cc193a5a187,273ffe3f0ee6f003,b32b6965c4ce864b,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359355d7b,676373f3933377a7
# Wavelet: e360ff9d8e272218
# Perceptual: 9ff80027fae286d1
# Difference: 0cd6303b3aceceb1
# Color: 09202008000
#
# img-mir-r-66-q40.jpg :
# Average: 063feefe9fa3ee40
# Crop Resistant: e3b6981d5458ceb2,95d1f2e68a961c73,12360c98b2e2830b,cc78b99ddddcc083,04d148f47a4991f3,0b79c84004c331bc,3ef988f825468898
# Wavelet: 023fecfe97a34640
# Perceptual: 979d013d1cd56572
# Difference: 3ef988f825468898
# Color: 11202008000
#
# img-mir-r-54-q10.jpg :
# Average: 0e3ceeffdb93e620
# Crop Resistant: eaa0999e6c69a767,29a6f6cd9b86bc31,39b17339bcd0c084,3666ec9833e1c182,c270fcbefc723e4e,d63878c84080a0d8,7ce19c282626ccc0,cb953231b35347c6
# Wavelet: 0438eeffd393e420
# Perceptual: 9699463d4ad63d70
# Difference: 7ce19c282626ccc0
# Color: 11202008000
#
# img-mir-r-47-q75.jpg :
# Average: 1c385efffb93f630
# Crop Resistant: c4a9bb96b829a734,5026f6cd9b868cb1,3933f13cbcc0e0c6,66aecc1933e1c104,edb070c8c080e0d8,62b13cdefc384e27,7ce29d282336a4e1,c386333133f36363
# Wavelet: 0c385effd393f200
# Perceptual: c49b463d4bd63872
# Difference: 7ce29d282336a4e1
# Color: 11202008000
#
# img-mir-q50.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,1899d80c8d9b1f27,dc2de99a909648e1,a498c97c365a3a1a,1b0380038f98f03f,322b6959d48c9e25,8d94f323a38c8c72,c00f0e38343c8fa6,2fe3953961114521,834f03135b072311
# Wavelet: c706ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94f323a38c8c72
# Color: 0a202000000
#
# img-mir-q20.jpg :
# Average: c742ffb971e4c418
# Crop Resistant: 64c4fc941c9898e8,1899d80c8d9b1e27,dc2de99a909648e1,a498c97c365a7a1e,1b0180038f98f03f,322b6979d48c9e2c,8d94b323a38c8c72,c00f0c38343c8fa6,2fe3953961134521,834f03135b072311
# Wavelet: c714ffb971e44418
# Perceptual: caad1572aab7d380
# Difference: 8d94b323a38c8c72
# Color: 01202000000

# %%
FRAME_INTERVAL = 1000 # 1 second

def compute_hashes(frame: Image):
    return {
        "img": str(uuid4()),
        "avg": ih.average_hash(frame),
        "crop": ih.crop_resistant_hash(frame),
        "whash": ih.whash(frame),
        "phash": ih.phash(frame),
        "dhash": ih.dhash(frame),
        "color": ih.colorhash(frame)
    }

def video_hashes(path: str) -> str:
    vidcap = cv2.VideoCapture(path)

    frame_count, fps = vidcap.get(cv2.CAP_PROP_FRAME_COUNT), vidcap.get(cv2.CAP_PROP_FPS)
    duration = (frame_count / fps * 1000) if fps > 0 else 0 # In milliseconds

    count, hashes = 0, []
    while True:
        if count >= duration: 
            break
        vidcap.set(cv2.CAP_PROP_POS_MSEC, count)
        print("Frame", count)
        success, image = vidcap.read()
        if not success:
            break

        hash = compute_hashes(Image.fromarray(image))
        hash["order"] = count // FRAME_INTERVAL
        hashes.append(hash)
        
        count += 2000

    return hashes

# %%
# orig = video_hashes("/mnt/c/Users/Breno/Downloads/ghqe/nok/b345aa54-44d8-4100-83ad-0ede47d9c563.m4v")
# print("Video 1")
crop = video_hashes("/mnt/c/Users/Breno/Downloads/ghqe/nok/00000000.m4v")
print("Video 2")

for original, hosh in zip(orig, crop):
    print(hosh["img"], ":")
    if hosh["avg"] == original["avg"]:
        print("Average:", original["avg"] - hosh["avg"], "=>", hosh["avg"] == original["avg"])

    if hosh["crop"] == original["crop"]:
        print("Crop Resistant:", original["crop"] - hosh["crop"], "=>", hosh["crop"] == original["crop"])
    
    if hosh["whash"] == original["whash"]:
        print("Wavelet:", original["whash"] - hosh["whash"], "=>", hosh["whash"] == original["whash"])
    
    if hosh["phash"] == original["phash"]:
        print("Perceptual:", original["phash"] - hosh["phash"], "=>", hosh["phash"] == original["phash"])
    
    if hosh["dhash"] == original["dhash"]:
        print("Difference:", original["dhash"] - hosh["dhash"], "=>", hosh["dhash"] == original["dhash"])
    
    if hosh["color"] == original["color"]:
        print("Color:", original["color"] - hosh["color"], "=>", hosh["color"] == original["color"])
    print()

# %%
# Out:
# img => a685a0e8-587a-4c65-a453-073ead553155
# avg => e342ff9d8e272318
# crop => d9dcc0d6c7e6e6e8,e766e4cf4e26071b,c44b68a6f696ed78,dae46cc193a5a187,273ffe3f0ee6f003,b32b6965c4ce864b,0cd6303b3aceceb1,fc0f8fe3d3c30e9a,0b38566359355d7b,676373f3933377a7
# whash => e360ff9d8e272218
# phash => 9ff80027fae286d1
# dhash => 0cd6303b3aceceb1
# color => 09202008000
